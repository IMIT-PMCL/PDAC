# %% [markdown]
# # 把SE{}移动到病人id文件夹下

# %%
import os
import shutil

def move_folders(source_dir):
    for root, dirs, files in os.walk(source_dir):
        for dirname in dirs:
            if dirname.startswith("EX"):
                ex_folder = os.path.join(root, dirname)
                patient_folder = os.path.dirname(os.path.dirname(os.path.dirname(ex_folder)))
                se_folders = [os.path.join(ex_folder, f"SE{i}") for i in range(1, 6)]
                for se_folder in se_folders:
                    if os.path.exists(se_folder):
                        new_se_folder = os.path.join(patient_folder, os.path.basename(se_folder))
                        try:
                            shutil.move(se_folder, new_se_folder)
                            print(f"Moved {se_folder} to {new_se_folder}")
                        except Exception as e:
                            print(f"Error moving {se_folder} to {new_se_folder}: {e}")
                try:
                    shutil.rmtree(os.path.dirname(os.path.dirname(ex_folder)))
                    print(f"Removed {os.path.dirname(os.path.dirname(ex_folder))}")
                except Exception as e:
                    print(f"Error removing {os.path.dirname(os.path.dirname(ex_folder))}: {e}")

source_dir = r"D:\A_Unnecessary_Dataset\DATA"

move_folders(source_dir)
# Out:
# Moved D:\A_Unnecessary_Dataset\DATA\00009048\20240424\142811\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00009048\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00009048\20240424\142811\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00009048\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00009048\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00010938\20240424\143039\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00010938\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00010938\20240424\143039\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00010938\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00010938\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00017139\20240424\143233\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00017139\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00017139\20240424\143233\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00017139\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00017139\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00022211\20240424\144448\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00022211\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00022211\20240424\144448\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00022211\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00022211\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00077790\20240424\143923\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00077790\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00077790\20240424\143923\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00077790\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00077790\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00085913\20240424\143954\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00085913\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00085913\20240424\143954\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00085913\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00085913\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00091222\20240424\144547\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00091222\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00091222\20240424\144547\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00091222\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00091222\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00093098\20240424\144802\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00093098\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00093098\20240424\144802\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00093098\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00093098\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00101172\20240424\144836\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00101172\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00101172\20240424\144836\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00101172\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00101172\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00103238\20240424\144957\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00103238\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00103238\20240424\144957\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00103238\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00103238\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00121468\20240424\145120\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00121468\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00121468\20240424\145120\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00121468\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00121468\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00123530\20240424\145227\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00123530\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00123530\20240424\145227\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00123530\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00123530\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00125017\20240424\145323\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00125017\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00125017\20240424\145323\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00125017\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00125017\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00146753\20240424\145419\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00146753\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00146753\20240424\145419\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00146753\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00146753\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00178228\20240424\145536\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00178228\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00178228\20240424\145536\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00178228\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00178228\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00180939\20240424\145621\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00180939\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00180939\20240424\145621\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00180939\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00180939\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00217441\20240424\145710\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00217441\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00217441\20240424\145710\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00217441\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00217441\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00220769\20240424\145837\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00220769\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00220769\20240424\145837\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00220769\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00220769\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00233340\20240424\145947\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00233340\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00233340\20240424\145947\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00233340\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00233340\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00233441\20240424\150027\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00233441\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00233441\20240424\150027\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00233441\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00233441\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00250989\20240424\150118\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00250989\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00250989\20240424\150118\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00250989\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00250989\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00253030\20240424\150219\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00253030\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00253030\20240424\150219\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00253030\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00253030\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00256302\20240424\150256\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00256302\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00256302\20240424\150256\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00256302\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00256302\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00260396\20240424\150334\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00260396\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00260396\20240424\150334\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00260396\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00260396\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00261333\20240424\150440\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00261333\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\00261333\20240424\150440\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\00261333\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\00261333\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\00261584\20240424\150516\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\00261584\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\
EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30023049\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30023049\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30023141\20240424\161456\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30023141\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30023141\20240424\161456\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30023141\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30023141\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30023344\20240424\161615\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30023344\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30023344\20240424\161615\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30023344\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30023344\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30023625\20240424\161744\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30023625\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30023625\20240424\161744\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30023625\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30023625\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30023633\20240424\161911\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30023633\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30023633\20240424\161911\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30023633\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30023633\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30023885\20240424\162035\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30023885\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30023885\20240424\162035\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30023885\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30023885\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30024443\20240424\171037\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30024443\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30024443\20240424\171037\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30024443\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30024443\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30025154\20240424\171220\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30025154\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30025154\20240424\171220\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30025154\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30025154\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30025276\20240424\171348\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30025276\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30025276\20240424\171348\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30025276\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30025276\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30025369\20240424\171540\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30025369\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30025369\20240424\171540\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30025369\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30025369\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30025423\20240424\171713\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30025423\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30025423\20240424\171713\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30025423\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30025423\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30025497\20240424\172941\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30025497\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30025497\20240424\172941\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30025497\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30025497\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30025548\20240424\173111\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30025548\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30025548\20240424\173111\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30025548\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30025548\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30025629\20240424\173300\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30025629\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30025629\20240424\173300\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30025629\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30025629\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30025817\20240424\173448\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30025817\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30025817\20240424\173448\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30025817\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30025817\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30026098\20240424\173832\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30026098\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30026098\20240424\173832\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30026098\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30026098\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30026656\20240424\174008\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30026656\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30026656\20240424\174008\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30026656\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30026656\20240424
# Moved D:\A_Unnecessary_Dataset\DATA\30026918\20240425\110855\EX1\SE1 to D:\A_Unnecessary_Dataset\DATA\30026918\SE1
# Moved D:\A_Unnecessary_Dataset\DATA\30026918\20240425\110855\EX1\SE2 to D:\A_Unnecessary_Dataset\DATA\30026918\SE2
# Removed D:\A_Unnecessary_Dataset\DATA\30026918\20240425

# %% [markdown]
# # 根据series number改文件夹名字

# %%
import os
import pydicom

def rename_folders(source_dir):
    for patient_folder in os.listdir(source_dir):
        patient_path = os.path.join(source_dir, patient_folder)
        if os.path.isdir(patient_path):
            for se_folder in os.listdir(patient_path):
                se_path = os.path.join(patient_path, se_folder)
                if os.path.isdir(se_path):
                    series_number = get_series_number(se_path)
                    if series_number:
                        new_name = os.path.join(patient_path, series_number)
                        try:
                            os.rename(se_path, new_name)
                            print(f"Renamed {se_path} to {new_name}")
                        except Exception as e:
                            print(f"Error renaming {se_path} to {new_name}: {e}")

def get_series_number(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            dicom_file = os.path.join(root, file)
            try:
                ds = pydicom.dcmread(dicom_file)
                series_number = str(ds.SeriesNumber)
                return series_number
            except Exception as e:
                print(f"Error reading SeriesNumber from {dicom_file}: {e}")
    return None

source_dir = 'G:/new/DATA'
rename_folders(source_dir)
# Out:
# Renamed G:/new/DATA\00022211\SE1 to G:/new/DATA\00022211\402
# Renamed G:/new/DATA\00022211\SE2 to G:/new/DATA\00022211\302
# Renamed G:/new/DATA\00022211\SE3 to G:/new/DATA\00022211\100
# Renamed G:/new/DATA\00022211\SE4 to G:/new/DATA\00022211\101
# Renamed G:/new/DATA\00022211\SE5 to G:/new/DATA\00022211\102
# Renamed G:/new/DATA\00180939\SE1 to G:/new/DATA\00180939\302
# Renamed G:/new/DATA\00180939\SE2 to G:/new/DATA\00180939\402
# Renamed G:/new/DATA\00180939\SE3 to G:/new/DATA\00180939\100
# Renamed G:/new/DATA\00180939\SE4 to G:/new/DATA\00180939\101
# Renamed G:/new/DATA\00180939\SE5 to G:/new/DATA\00180939\102
# Renamed G:/new/DATA\00233441\SE1 to G:/new/DATA\00233441\402
# Renamed G:/new/DATA\00233441\SE2 to G:/new/DATA\00233441\302
# Renamed G:/new/DATA\00233441\SE3 to G:/new/DATA\00233441\100
# Renamed G:/new/DATA\00233441\SE4 to G:/new/DATA\00233441\101
# Renamed G:/new/DATA\00233441\SE5 to G:/new/DATA\00233441\102
# Renamed G:/new/DATA\00260396\SE1 to G:/new/DATA\00260396\303
# Renamed G:/new/DATA\00260396\SE2 to G:/new/DATA\00260396\403
# Renamed G:/new/DATA\00260396\SE3 to G:/new/DATA\00260396\100
# Renamed G:/new/DATA\00260396\SE4 to G:/new/DATA\00260396\101
# Renamed G:/new/DATA\00260396\SE5 to G:/new/DATA\00260396\102
# Renamed G:/new/DATA\00261584\SE1 to G:/new/DATA\00261584\403
# Renamed G:/new/DATA\00261584\SE2 to G:/new/DATA\00261584\303
# Renamed G:/new/DATA\00261584\SE3 to G:/new/DATA\00261584\101
# Renamed G:/new/DATA\00261584\SE4 to G:/new/DATA\00261584\102
# Renamed G:/new/DATA\00261584\SE5 to G:/new/DATA\00261584\103
# Renamed G:/new/DATA\00262830\SE1 to G:/new/DATA\00262830\403
# Renamed G:/new/DATA\00262830\SE2 to G:/new/DATA\00262830\303
# Renamed G:/new/DATA\00262830\SE3 to G:/new/DATA\00262830\100
# Renamed G:/new/DATA\00262830\SE4 to G:/new/DATA\00262830\101
# Renamed G:/new/DATA\00262830\SE5 to G:/new/DATA\00262830\102
# Renamed G:/new/DATA\00263091\SE1 to G:/new/DATA\00263091\101
# Renamed G:/new/DATA\00263091\SE2 to G:/new/DATA\00263091\103
# Renamed G:/new/DATA\00263091\SE3 to G:/new/DATA\00263091\102
# Renamed G:/new/DATA\00263091\SE4 to G:/new/DATA\00263091\303
# Renamed G:/new/DATA\00263091\SE5 to G:/new/DATA\00263091\403
# Renamed G:/new/DATA\00264055\SE1 to G:/new/DATA\00264055\403
# Renamed G:/new/DATA\00264055\SE2 to G:/new/DATA\00264055\303
# Renamed G:/new/DATA\00264055\SE3 to G:/new/DATA\00264055\101
# Renamed G:/new/DATA\00264055\SE4 to G:/new/DATA\00264055\102
# Renamed G:/new/DATA\00264055\SE5 to G:/new/DATA\00264055\100
# Renamed G:/new/DATA\10002188\SE1 to G:/new/DATA\10002188\402
# Renamed G:/new/DATA\10002188\SE2 to G:/new/DATA\10002188\100
# Renamed G:/new/DATA\10002188\SE3 to G:/new/DATA\10002188\302
# Renamed G:/new/DATA\10002188\SE4 to G:/new/DATA\10002188\101
# Renamed G:/new/DATA\10002188\SE5 to G:/new/DATA\10002188\102
# Renamed G:/new/DATA\30015941\SE1 to G:/new/DATA\30015941\402
# Renamed G:/new/DATA\30015941\SE2 to G:/new/DATA\30015941\302
# Renamed G:/new/DATA\30015941\SE3 to G:/new/DATA\30015941\102
# Renamed G:/new/DATA\30015941\SE4 to G:/new/DATA\30015941\103
# %%
import os

def create_folders(source_dir):
    for patient_folder in os.listdir(source_dir):
        patient_path = os.path.join(source_dir, patient_folder)
        if os.path.isdir(patient_path):
            mask_folder = os.path.join(patient_path, "Mask")
            image_folder = os.path.join(patient_path, "Image")
            os.makedirs(mask_folder, exist_ok=True)
            os.makedirs(image_folder, exist_ok=True)
            print(f"Created Mask and Image folders for patient {patient_folder}")

source_dir = 'G:/new/DATA'
create_folders(source_dir)
# Out:
# Created Mask and Image folders for patient 00022211
# Created Mask and Image folders for patient 00180939
# Created Mask and Image folders for patient 00233441
# Created Mask and Image folders for patient 00260396
# Created Mask and Image folders for patient 00261584
# Created Mask and Image folders for patient 00262830
# Created Mask and Image folders for patient 00263091
# Created Mask and Image folders for patient 00264055
# Created Mask and Image folders for patient 10002188
# Created Mask and Image folders for patient 30015941
# Created Mask and Image folders for patient 30017387
# Created Mask and Image folders for patient 30018487
# Created Mask and Image folders for patient 30018730
# Created Mask and Image folders for patient 30018913
# Created Mask and Image folders for patient 30019687
# Created Mask and Image folders for patient 30022603
# Created Mask and Image folders for patient 30025369
# Created Mask and Image folders for patient 30025497
# Created Mask and Image folders for patient 30026656
# Created Mask and Image folders for patient 30027866
# Created Mask and Image folders for patient 30029428
# Created Mask and Image folders for patient 30032091
# Created Mask and Image folders for patient 30038077
# Created Mask and Image folders for patient 30045514
# Created Mask and Image folders for patient 30045599
# Created Mask and Image folders for patient 30120308

# %% [markdown]
# # 把302和402放到Image文件夹，剩下的放到Mask文件夹

# %%
import os
import shutil

def organize_folders(source_dir):
    for patient_folder in os.listdir(source_dir):
        patient_path = os.path.join(source_dir, patient_folder)
        if os.path.isdir(patient_path):
            mask_folder = None
            image_folder = None
            for sub_folder in os.listdir(patient_path):
                sub_folder_path = os.path.join(patient_path, sub_folder)
                if os.path.isdir(sub_folder_path):
                    if sub_folder == "Image":
                        image_folder = sub_folder_path
                    elif sub_folder == "Mask":
                        mask_folder = sub_folder_path
            
            if not mask_folder or not image_folder:
                print(f"Error: Mask or Image folder not found for patient {patient_folder}")
                continue

            # Move folders to Mask or Image directory
            for folder_name in os.listdir(patient_path):
                folder_path = os.path.join(patient_path, folder_name)
                if os.path.isdir(folder_path):
                    if folder_name in ["302", "402", "303", "403"]:
                        target_folder = image_folder
                    elif folder_name not in ["Image", "Mask"]:
                        target_folder = mask_folder
                    else:
                        continue  # Skip Image and Mask folders
                    if folder_path != target_folder:  # Avoid moving to itself
                        try:
                            shutil.move(folder_path, os.path.join(target_folder, folder_name))
                            print(f"Moved {folder_path} to {target_folder}")
                        except Exception as e:
                            print(f"Error moving {folder_path} to {target_folder}: {e}")

source_dir = 'G:/new/DATA'
organize_folders(source_dir)
# Out:
# Moved G:/new/DATA\00022211\100 to G:/new/DATA\00022211\Mask
# Moved G:/new/DATA\00022211\101 to G:/new/DATA\00022211\Mask
# Moved G:/new/DATA\00022211\102 to G:/new/DATA\00022211\Mask
# Moved G:/new/DATA\00022211\302 to G:/new/DATA\00022211\Image
# Moved G:/new/DATA\00022211\402 to G:/new/DATA\00022211\Image
# Moved G:/new/DATA\00180939\100 to G:/new/DATA\00180939\Mask
# Moved G:/new/DATA\00180939\101 to G:/new/DATA\00180939\Mask
# Moved G:/new/DATA\00180939\102 to G:/new/DATA\00180939\Mask
# Moved G:/new/DATA\00180939\302 to G:/new/DATA\00180939\Image
# Moved G:/new/DATA\00180939\402 to G:/new/DATA\00180939\Image
# Moved G:/new/DATA\00233441\100 to G:/new/DATA\00233441\Mask
# Moved G:/new/DATA\00233441\101 to G:/new/DATA\00233441\Mask
# Moved G:/new/DATA\00233441\102 to G:/new/DATA\00233441\Mask
# Moved G:/new/DATA\00233441\302 to G:/new/DATA\00233441\Image
# Moved G:/new/DATA\00233441\402 to G:/new/DATA\00233441\Image
# Moved G:/new/DATA\00260396\100 to G:/new/DATA\00260396\Mask
# Moved G:/new/DATA\00260396\101 to G:/new/DATA\00260396\Mask
# Moved G:/new/DATA\00260396\102 to G:/new/DATA\00260396\Mask
# Moved G:/new/DATA\00260396\303 to G:/new/DATA\00260396\Image
# Moved G:/new/DATA\00260396\403 to G:/new/DATA\00260396\Image
# Moved G:/new/DATA\00261584\101 to G:/new/DATA\00261584\Mask
# Moved G:/new/DATA\00261584\102 to G:/new/DATA\00261584\Mask
# Moved G:/new/DATA\00261584\103 to G:/new/DATA\00261584\Mask
# Moved G:/new/DATA\00261584\303 to G:/new/DATA\00261584\Image
# Moved G:/new/DATA\00261584\403 to G:/new/DATA\00261584\Image
# Moved G:/new/DATA\00262830\100 to G:/new/DATA\00262830\Mask
# Moved G:/new/DATA\00262830\101 to G:/new/DATA\00262830\Mask
# Moved G:/new/DATA\00262830\102 to G:/new/DATA\00262830\Mask
# Moved G:/new/DATA\00262830\303 to G:/new/DATA\00262830\Image
# Moved G:/new/DATA\00262830\403 to G:/new/DATA\00262830\Image
# Moved G:/new/DATA\00263091\101 to G:/new/DATA\00263091\Mask
# Moved G:/new/DATA\00263091\102 to G:/new/DATA\00263091\Mask
# Moved G:/new/DATA\00263091\103 to G:/new/DATA\00263091\Mask
# Moved G:/new/DATA\00263091\303 to G:/new/DATA\00263091\Image
# Moved G:/new/DATA\00263091\403 to G:/new/DATA\00263091\Image
# Moved G:/new/DATA\00264055\100 to G:/new/DATA\00264055\Mask
# Moved G:/new/DATA\00264055\101 to G:/new/DATA\00264055\Mask
# Moved G:/new/DATA\00264055\102 to G:/new/DATA\00264055\Mask
# Moved G:/new/DATA\00264055\303 to G:/new/DATA\00264055\Image
# Moved G:/new/DATA\00264055\403 to G:/new/DATA\00264055\Image
# Moved G:/new/DATA\10002188\100 to G:/new/DATA\10002188\Mask
# Moved G:/new/DATA\10002188\101 to G:/new/DATA\10002188\Mask
# Moved G:/new/DATA\10002188\102 to G:/new/DATA\10002188\Mask
# Moved G:/new/DATA\10002188\302 to G:/new/DATA\10002188\Image
# Moved G:/new/DATA\10002188\402 to G:/new/DATA\10002188\Image
# Moved G:/new/DATA\30015941\102 to G:/new/DATA\30015941\Mask
# Moved G:/new/DATA\30015941\103 to G:/new/DATA\30015941\Mask
# Moved G:/new/DATA\30015941\104 to G:/new/DATA\30015941\Mask
# Moved G:/new/DATA\30015941\302 to G:/new/DATA\30015941\Image
# Moved G:/new/DATA\30015941\402 to G:/new/DATA\30015941\Image
# Moved G:/new/DATA\30017387\100 to G:/new/DATA\30017387\Mask
# Moved G:/new/DATA\30017387\101 to G:/new/DATA\30017387\Mask
# Moved G:/new/DATA\30017387\102 to G:/new/DATA\30017387\Mask
# Moved G:/new/DATA\30017387\302 to G:/new/DATA\30017387\Image
# Moved G:/new/DATA\30017387\402 to G:/new/DATA\30017387\Image
# Moved G:/new/DATA\30018487\100 to G:/new/DATA\30018487\Mask
# Moved G:/new/DATA\30018487\101 to G:/new/DATA\30018487\Mask
# Moved G:/new/DATA\30018487\102 to G:/new/DATA\30018487\Mask
# Moved G:/new/DATA\30018487\302 to G:/new/DATA\30018487\Image
# Moved G:/new/DATA\30018487\402 to G:/new/DATA\30018487\Image
# Moved G:/new/DATA\30018730\101 to G:/new/DATA\30018730\Mask
# Moved G:/new/DATA\30018730\103 to G:/new/DATA\30018730\Mask
# Moved G:/new/DATA\30018730\104 to G:/new/DATA\30018730\Mask
# Moved G:/new/DATA\30018730\302 to G:/new/DATA\30018730\Image
# Moved G:/new/DATA\30018730\402 to G:/new/DATA\30018730\Image
# Moved G:/new/DATA\30018913\100 to G:/new/DATA\30018913\Mask
# Moved G:/new/DATA\30018913\101 to G:/new/DATA\30018913\Mask
# Moved G:/new/DATA\30018913\102 to G:/new/DATA\30018913\Mask
# Moved G:/new/DATA\30018913\302 to G:/new/DATA\30018913\Image
# Moved G:/new/DATA\30018913\402 to G:/new/DATA\30018913\Image
# Moved G:/new/DATA\30019687\100 to G:/new/DATA\30019687\Mask
# Moved G:/new/DATA\30019687\101 to G:/new/DATA\30019687\Mask
# Moved G:/new/DATA\30019687\102 to G:/new/DATA\30019687\Mask
# Moved G:/new/DATA\30019687\302 to G:/new/DATA\30019687\Image
# Moved G:/new/DATA\30019687\402 to G:/new/DATA\30019687\Image
# Moved G:/new/DATA\30022603\100 to G:/new/DATA\30022603\Mask
# Moved G:/new/DATA\30022603\101 to G:/new/DATA\30022603\Mask
# Moved G:/new/DATA\30022603\102 to G:/new/DATA\30022603\Mask
# Moved G:/new/DATA\30022603\302 to G:/new/DATA\30022603\Image
# Moved G:/new/DATA\30022603\402 to G:/new/DATA\30022603\Image
# Moved G:/new/DATA\30025369\100 to G:/new/DATA\30025369\Mask
# Moved G:/new/DATA\30025369\101 to G:/new/DATA\30025369\Mask
# Moved G:/new/DATA\30025369\102 to G:/new/DATA\30025369\Mask
# Moved G:/new/DATA\30025369\302 to G:/new/DATA\30025369\Image
# Moved G:/new/DATA\30025369\402 to G:/new/DATA\30025369\Image
# Moved G:/new/DATA\30025497\101 to G:/new/DATA\30025497\Mask
# Moved G:/new/DATA\30025497\102 to G:/new/DATA\30025497\Mask
# Moved G:/new/DATA\30025497\103 to G:/new/DATA\30025497\Mask
# Moved G:/new/DATA\30025497\302 to G:/new/DATA\30025497\Image
# Moved G:/new/DATA\30025497\402 to G:/new/DATA\30025497\Image
# Moved G:/new/DATA\30026656\100 to G:/new/DATA\30026656\Mask
# Moved G:/new/DATA\30026656\101 to G:/new/DATA\30026656\Mask
# Moved G:/new/DATA\30026656\102 to G:/new/DATA\30026656\Mask
# Moved G:/new/DATA\30026656\302 to G:/new/DATA\30026656\Image
# Moved G:/new/DATA\30026656\402 to G:/new/DATA\30026656\Image
# Moved G:/new/DATA\30027866\100 to G:/new/DATA\30027866\Mask
# Moved G:/new/DATA\30027866\102 to G:/new/DATA\30027866\Mask
# Moved G:/new/DATA\30027866\103 to G:/new/DATA\30027866\Mask
# Moved G:/new/DATA\30027866\302 to G:/new/DATA\30027866\Image
# Moved G:/new/DATA\30027866\402 to G:/new/DATA\30027866\Image
# Moved G:/new/DATA\30029428\100 to G:/new/DATA\30029428\Mask
# Moved G:/new/DATA\30029428\101 to G:/new/DATA\30029428\Mask
# Moved G:/new/DATA\30029428\102 to G:/new/DATA\30029428\Mask
# Moved G:/new/DATA\30029428\302 to G:/new/DATA\30029428\Image
# Moved G:/new/DATA\30029428\402 to G:/new/DATA\30029428\Image
# Moved G:/new/DATA\30032091\102 to G:/new/DATA\30032091\Mask
# Moved G:/new/DATA\30032091\103 to G:/new/DATA\30032091\Mask
# Moved G:/new/DATA\30032091\104 to G:/new/DATA\30032091\Mask
# Moved G:/new/DATA\30032091\302 to G:/new/DATA\30032091\Image
# Moved G:/new/DATA\30032091\402 to G:/new/DATA\30032091\Image
# Moved G:/new/DATA\30038077\100 to G:/new/DATA\30038077\Mask
# Moved G:/new/DATA\30038077\101 to G:/new/DATA\30038077\Mask
# Moved G:/new/DATA\30038077\102 to G:/new/DATA\30038077\Mask
# Moved G:/new/DATA\30038077\302 to G:/new/DATA\30038077\Image
# Moved G:/new/DATA\30038077\402 to G:/new/DATA\30038077\Image
# Moved G:/new/DATA\30045514\101 to G:/new/DATA\30045514\Mask
# Moved G:/new/DATA\30045514\102 to G:/new/DATA\30045514\Mask
# Moved G:/new/DATA\30045514\103 to G:/new/DATA\30045514\Mask
# Moved G:/new/DATA\30045514\302 to G:/new/DATA\30045514\Image
# Moved G:/new/DATA\30045514\402 to G:/new/DATA\30045514\Image
# Moved G:/new/DATA\30045599\100 to G:/new/DATA\30045599\Mask
# Moved G:/new/DATA\30045599\101 to G:/new/DATA\30045599\Mask
# Moved G:/new/DATA\30045599\102 to G:/new/DATA\30045599\Mask
# Moved G:/new/DATA\30045599\302 to G:/new/DATA\30045599\Image
# Moved G:/new/DATA\30045599\402 to G:/new/DATA\30045599\Image
# Moved G:/new/DATA\30120308\101 to G:/new/DATA\30120308\Mask
# Moved G:/new/DATA\30120308\102 to G:/new/DATA\30120308\Mask
# Moved G:/new/DATA\30120308\103 to G:/new/DATA\30120308\Mask
# Moved G:/new/DATA\30120308\302 to G:/new/DATA\30120308\Image
# Moved G:/new/DATA\30120308\402 to G:/new/DATA\30120308\Image

# %%
import os

def rename_folders(source_dir):
    for patient_folder in os.listdir(source_dir):
        patient_path = os.path.join(source_dir, patient_folder)
        if os.path.isdir(patient_path):
            image_folder = os.path.join(patient_path, "Image")
            if os.path.exists(image_folder):
                for image_subfolder in os.listdir(image_folder):
                    image_subfolder_path = os.path.join(image_folder, image_subfolder)
                    if os.path.isdir(image_subfolder_path):
                        if image_subfolder == "302":
                            new_name = "A"
                        elif image_subfolder == "403":
                            new_name = "A"
                        elif image_subfolder == "402":
                            new_name = "V"
                        elif image_subfolder == "403":
                            new_name = "V"
                        else:
                            continue
                        try:
                            os.rename(image_subfolder_path, os.path.join(image_folder, new_name))
                            print(f"Renamed {image_subfolder_path} to {new_name}")
                        except Exception as e:
                            print(f"Error renaming {image_subfolder_path}: {e}")

source_dir = 'G:/new/DATA'
rename_folders(source_dir)
# Out:
# Renamed G:/new/DATA\00022211\Image\302 to A
# Renamed G:/new/DATA\00022211\Image\402 to V
# Renamed G:/new/DATA\00180939\Image\302 to A
# Renamed G:/new/DATA\00180939\Image\402 to V
# Renamed G:/new/DATA\00233441\Image\302 to A
# Renamed G:/new/DATA\00233441\Image\402 to V
# Renamed G:/new/DATA\00260396\Image\403 to A
# Renamed G:/new/DATA\00261584\Image\403 to A
# Renamed G:/new/DATA\00262830\Image\403 to A
# Renamed G:/new/DATA\00263091\Image\403 to A
# Renamed G:/new/DATA\00264055\Image\403 to A
# Renamed G:/new/DATA\10002188\Image\302 to A
# Renamed G:/new/DATA\10002188\Image\402 to V
# Renamed G:/new/DATA\30015941\Image\302 to A
# Renamed G:/new/DATA\30015941\Image\402 to V
# Renamed G:/new/DATA\30017387\Image\302 to A
# Renamed G:/new/DATA\30017387\Image\402 to V
# Renamed G:/new/DATA\30018487\Image\302 to A
# Renamed G:/new/DATA\30018487\Image\402 to V
# Renamed G:/new/DATA\30018730\Image\302 to A
# Renamed G:/new/DATA\30018730\Image\402 to V
# Renamed G:/new/DATA\30018913\Image\302 to A
# Renamed G:/new/DATA\30018913\Image\402 to V
# Renamed G:/new/DATA\30019687\Image\302 to A
# Renamed G:/new/DATA\30019687\Image\402 to V
# Renamed G:/new/DATA\30022603\Image\302 to A
# Renamed G:/new/DATA\30022603\Image\402 to V
# Renamed G:/new/DATA\30025369\Image\302 to A
# Renamed G:/new/DATA\30025369\Image\402 to V
# Renamed G:/new/DATA\30025497\Image\302 to A
# Renamed G:/new/DATA\30025497\Image\402 to V
# Renamed G:/new/DATA\30026656\Image\302 to A
# Renamed G:/new/DATA\30026656\Image\402 to V
# Renamed G:/new/DATA\30027866\Image\302 to A
# Renamed G:/new/DATA\30027866\Image\402 to V
# Renamed G:/new/DATA\30029428\Image\302 to A
# Renamed G:/new/DATA\30029428\Image\402 to V
# Renamed G:/new/DATA\30032091\Image\302 to A
# Renamed G:/new/DATA\30032091\Image\402 to V
# Renamed G:/new/DATA\30038077\Image\302 to A
# Renamed G:/new/DATA\30038077\Image\402 to V
# Renamed G:/new/DATA\30045514\Image\302 to A
# Renamed G:/new/DATA\30045514\Image\402 to V
# Renamed G:/new/DATA\30045599\Image\302 to A
# Renamed G:/new/DATA\30045599\Image\402 to V
# Renamed G:/new/DATA\30120308\Image\302 to A
# Renamed G:/new/DATA\30120308\Image\402 to V

# %% [markdown]
# # 转成nii.gz格式并且把方向标准化为RPS

# %%
import os
import SimpleITK as sitk

def get_curr_orient(image):
    curr_orient = sitk.DICOMOrientImageFilter_GetOrientationFromDirectionCosines(image.GetDirection())
    return curr_orient

def correct_orientation(image, target_orientation="RPS"):
    curr_orient = get_curr_orient(image)
    if curr_orient != target_orientation:
        image = sitk.DICOMOrient(image, target_orientation)
    print("current orientation:", get_curr_orient(image))
    return image

# 定义输入和输出路径
input_data_path = "G:/new/DATA"
output_data_path = "G:/new/DATA2"

# 创建输出文件夹
os.makedirs(output_data_path, exist_ok=True)

# 遍历每个病人文件夹
for patient_folder in os.listdir(input_data_path):
    patient_path = os.path.join(input_data_path, patient_folder)
    output_patient_path = os.path.join(output_data_path, patient_folder)

    # 检查Image和Mask文件夹是否存在
    for folder in ["Image", "Mask"]:
        folder_path = os.path.join(patient_path, folder)
        if not os.path.exists(folder_path):
            print(f"Error: {folder} folder not found for patient {patient_folder}")
            continue

        output_folder_path = os.path.join(output_patient_path, folder)

        # 创建输出文件夹
        os.makedirs(output_folder_path, exist_ok=True)

        # 遍历DICOM文件夹
        for subfolder in os.listdir(folder_path):
            subfolder_path = os.path.join(folder_path, subfolder)
            if not os.path.isdir(subfolder_path):
                continue

            output_subfolder_path = os.path.join(output_folder_path, subfolder)

            # 转换dicom文件为nii.gz文件
            reader = sitk.ImageSeriesReader()
            dicom_names = reader.GetGDCMSeriesFileNames(subfolder_path)
            reader.SetFileNames(dicom_names)
            image = reader.Execute()

            # 标准化方向
            image = correct_orientation(image)

            # 保存为Nii.gz格式
            sitk.WriteImage(image, output_subfolder_path + ".nii.gz")
# Out:
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS
# current orientation: RPS

# %% [markdown]
# # 修改intensity

# %%
import os
import SimpleITK as sitk
import numpy as np

# 定义输入和输出路径
input_data_path = "G:/new/DATA2"
output_data_path = "G:/new/DATA2"

# 遍历每个病人文件夹
for patient_folder in os.listdir(input_data_path):
    patient_path = os.path.join(input_data_path, patient_folder)
    output_patient_path = os.path.join(output_data_path, patient_folder)

    # 检查Mask文件夹是否存在
    mask_folder_path = os.path.join(patient_path, "Mask")
    if not os.path.exists(mask_folder_path):
        print(f"Error: Mask folder not found for patient {patient_folder}")
        continue

    # 创建输出文件夹
    os.makedirs(output_patient_path, exist_ok=True)
    output_mask_folder_path = os.path.join(output_patient_path, "Mask")
    os.makedirs(output_mask_folder_path, exist_ok=True)

    # 遍历Mask文件夹下的nii.gz文件
    for filename in os.listdir(mask_folder_path):
        if not filename.endswith(".nii.gz"):
            continue

        # 读取nii.gz文件
        mask_path = os.path.join(mask_folder_path, filename)
        mask = sitk.ReadImage(mask_path)

        # 修改像素值
        mask_array = sitk.GetArrayFromImage(mask)
        mask_array[mask_array == -1024] = 0
        mask_array[mask_array != 0] = 1

        # 创建新的SimpleITK图像对象
        modified_mask = sitk.GetImageFromArray(mask_array)
        modified_mask.CopyInformation(mask)

        # 保存修改后的nii.gz文件
        output_mask_path = os.path.join(output_mask_folder_path, filename)
        sitk.WriteImage(modified_mask, output_mask_path)

print("Intensity modification completed.")
# Out:
# Intensity modification completed.

# %% [markdown]
# # 区分动静脉mask（重命名为Artery和Vein）

# %%
import os
import pydicom

folder_path = r'D:\A_Unnecessary_Dataset\DATA'

for patient_folder in os.listdir(folder_path):
    patient_folder_path = os.path.join(folder_path, patient_folder)
    if os.path.isdir(patient_folder_path):

        for se_folder in os.listdir(patient_folder_path):
            se_folder_path = os.path.join(patient_folder_path, se_folder)
            if os.path.isdir(se_folder_path):

                dicom_files = [f for f in os.listdir(se_folder_path) if os.path.isfile(os.path.join(se_folder_path, f))]
                if dicom_files:
                    first_dicom_file_path = os.path.join(se_folder_path, dicom_files[0])
                    try:
                        ds = pydicom.dcmread(first_dicom_file_path)
                        series_description = ds.SeriesDescription

                        if '302' in series_description or '303' in series_description:
                            new_folder_name = 'Artery'
                        elif '402' in series_description or '403' in series_description:
                            new_folder_name = 'Vein'
                        else:
                            new_folder_name = se_folder

                        if new_folder_name != se_folder:
                            os.rename(se_folder_path, os.path.join(patient_folder_path, new_folder_name))
                            print(f"Renamed '{se_folder}' to '{new_folder_name}'")
                    except Exception as e:
                        print(f"Error processing {first_dicom_file_path}: {e}")
# Out:
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'SE2' to 'Vein'
# Error processing D:\A_Unnecessary_Dataset\DATA\00217441\Series 402)\IMG1: [WinError 183] 当文件已存在时，无法创建该文件。: 'D:\\A_Unnecessary_Dataset\\DATA\\00217441\\Series 402)' -> 'D:\\A_Unnecessary_Dataset\\DATA\\00217441\\Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 303)' to 'Artery'
# Renamed 'Series 403)' to 'Vein'
# Renamed 'Series 303)' to 'Artery'
# Renamed 'Series 403)' to 'Vein'
# Renamed 'Series 303)' to 'Artery'
# Renamed 'Series 403)' to 'Vein'
# Renamed 'Series 303)' to 'Artery'
# Renamed 'Series 403)' to 'Vein'
# Renamed 'Series 303)' to 'Artery'
# Renamed 'Series 403)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'SE2' to 'Artery'
# Error processing D:\A_Unnecessary_Dataset\DATA\10026175\Series 302)\IMG1: [WinError 183] 当文件已存在时，无法创建该文件。: 'D:\\A_Unnecessary_Dataset\\DATA\\10026175\\Series 302)' -> 'D:\\A_Unnecessary_Dataset\\DATA\\10026175\\Artery'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'
# Renamed 'Series 302)' to 'Artery'
# Renamed 'Series 402)' to 'Vein'

# %% [markdown]
# # 只把Image文件夹dicom里的转nii

# %%
import os
import SimpleITK as sitk

def get_curr_orient(image):
    curr_orient = sitk.DICOMOrientImageFilter_GetOrientationFromDirectionCosines(image.GetDirection())
    return curr_orient

def correct_orientation(image, target_orientation="RPS"):
    curr_orient = get_curr_orient(image)
    if curr_orient != target_orientation:
        image = sitk.DICOMOrient(image, target_orientation)
    print("current orientation:", get_curr_orient(image))
    return image

input_data_path = "/Volumes/KESU/0407data/DATA"
output_data_path = "/Volumes/KESU/0407data/DATA2"

os.makedirs(output_data_path, exist_ok=True)

for patient_folder in os.listdir(input_data_path):
    patient_path = os.path.join(input_data_path, patient_folder)
    output_patient_path = os.path.join(output_data_path, patient_folder)

    image_folder_path = os.path.join(patient_path, "Image")
    if not os.path.exists(image_folder_path):
        print(f"Error: Image folder not found for patient {patient_folder}")
        continue

    output_image_folder_path = os.path.join(output_patient_path, "Image")

    os.makedirs(output_image_folder_path, exist_ok=True)

    for subfolder in os.listdir(image_folder_path):
        subfolder_path = os.path.join(image_folder_path, subfolder)
        if not os.path.isdir(subfolder_path):
            continue

        output_subfolder_path = os.path.join(output_image_folder_path, subfolder)

        reader = sitk.ImageSeriesReader()
        dicom_names = reader.GetGDCMSeriesFileNames(subfolder_path)
        reader.SetFileNames(dicom_names)
        image = reader.Execute()

        image = correct_orientation(image)

        sitk.WriteImage(image, output_subfolder_path + ".nii.gz")

# %% [markdown]
# # 根据Series Number重命名mask（+当文件夹中有三个dicom，且其中两个根据Series Number分别重命名为了Artery和Vein，则第三个文件夹命名为Tumor

# %%
import os
import pydicom

folder_path = r'D:\A_Unnecessary_Dataset\DATA'

for patient_folder in os.listdir(folder_path):
    patient_folder_path = os.path.join(folder_path, patient_folder)
    if os.path.isdir(patient_folder_path):
        se_folders = [f for f in os.listdir(patient_folder_path) if os.path.isdir(os.path.join(patient_folder_path, f))]

        if len(se_folders) == 3:
            renamed_folders = []
            for se_folder in se_folders:
                se_folder_path = os.path.join(patient_folder_path, se_folder)
                dicom_files = [f for f in os.listdir(se_folder_path) if os.path.isfile(os.path.join(se_folder_path, f))]
                
                if dicom_files:
                    first_dicom_file_path = os.path.join(se_folder_path, dicom_files[0])
                    try:
                        ds = pydicom.dcmread(first_dicom_file_path)
                        series_description = ds.SeriesDescription

                        if '302' in series_description or '303' in series_description:
                            new_folder_name = 'Artery'
                        elif '402' in series_description or '403' in series_description:
                            new_folder_name = 'Vein'
                        else:
                            new_folder_name = se_folder

                        if new_folder_name != se_folder:
                            os.rename(se_folder_path, os.path.join(patient_folder_path, new_folder_name))
                            renamed_folders.append(new_folder_name)
                            print(f"Renamed '{se_folder}' to '{new_folder_name}'")
                    except Exception as e:
                        print(f"Error processing {first_dicom_file_path}: {e}")

            if len(renamed_folders) == 2:
                for se_folder in se_folders:
                    if se_folder not in renamed_folders:
                        os.rename(os.path.join(patient_folder_path, se_folder), os.path.join(patient_folder_path, 'Tumor'))
                        print(f"Renamed '{se_folder}' to 'Tumor'")
        
        else:
            for se_folder in se_folders:
                se_folder_path = os.path.join(patient_folder_path, se_folder)
                dicom_files = [f for f in os.listdir(se_folder_path) if os.path.isfile(os.path.join(se_folder_path, f))]
                
                if dicom_files:
                    first_dicom_file_path = os.path.join(se_folder_path, dicom_files[0])
                    try:
                        ds = pydicom.dcmread(first_dicom_file_path)
                        series_description = ds.SeriesDescription

                        if '302' in series_description or '303' in series_description:
                            new_folder_name = 'Artery'
                        elif '402' in series_description or '403' in series_description:
                            new_folder_name = 'Vein'
                        else:
                            new_folder_name = se_folder

                        if new_folder_name != se_folder:
                            os.rename(se_folder_path, os.path.join(patient_folder_path, new_folder_name))
                            print(f"Renamed '{se_folder}' to '{new_folder_name}'")
                    except Exception as e:
                        print(f"Error processing {first_dicom_file_path}: {e}")
